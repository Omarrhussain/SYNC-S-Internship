# %% [markdown]
# <a href="https://colab.research.google.com/github/Omarrhussain/SYNC-S-Internship/blob/main/Boston_House_Price_Predictions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing Libraries 📚

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn import metrics

import warnings
warnings.filterwarnings('ignore')

# %%
df_train = pd.read_csv('/content/boston_train.csv')
df_train
# Out:
#       ID     crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0      1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1      2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2      4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 3      5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# 4      7  0.08829  12.5   7.87     0  0.524  6.012  66.6  5.5605    5  311
# ..   ...      ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 328  500  0.17783   0.0   9.69     0  0.585  5.569  73.5  2.3999    6  391
# 329  502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 330  503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 331  504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 332  506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       18.7  394.63   2.94  33.4
# 3       18.7  396.90   5.33  36.2
# 4       15.2  395.60  12.43  22.9
# ..       ...     ...    ...   ...
# 328     19.2  395.77  15.10  17.5
# 329     21.0  391.99   9.67  22.4
# 330     21.0  396.90   9.08  20.6
# 331     21.0  396.90   5.64  23.9
# 332     21.0  396.90   7.88  11.9
#
# [333 rows x 15 columns]

# %%
df_train.head().style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_2d928" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_2d928_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_2d928_level0_col1" class="col_heading level0 col1" >crim</th>
#       <th id="T_2d928_level0_col2" class="col_heading level0 col2" >zn</th>
#       <th id="T_2d928_level0_col3" class="col_heading level0 col3" >indus</th>
#       <th id="T_2d928_level0_col4" class="col_heading level0 col4" >chas</th>
#       <th id="T_2d928_level0_col5" class="col_heading level0 col5" >nox</th>
#       <th id="T_2d928_level0_col6" class="col_heading level0 col6" >rm</th>
#       <th id="T_2d928_level0_col7" class="col_heading level0 col7" >age</th>
#       <th id="T_2d928_level0_col8" class="col_heading level0 col8" >dis</th>
#       <th id="T_2d928_level0_col9" class="col_heading level0 col9" >rad</th>
#       <th id="T_2d928_level0_col10" class="col_heading level0 col10" >tax</th>
#       <th id="T_2d928_level0_col11" class="col_heading level0 col11" >ptratio</th>
#       <th id="T_2d928_level0_col12" class="col_heading level0 col12" >black</th>
#       <th id="T_2d928_level0_col13" class="col_heading level0 col13" >lstat</th>
#       <th id="T_2d928_level0_col14" class="col_heading level0 col14" >medv</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_2d928_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_2d928_row0_col1" class="data row0 col1" >0.006320</td>
#       <td id="T_2d928_row0_col2" class="data row0 col2" >18.000000</td>
#       <td id="T_2d928_row0_col3" class="data row0 col3" >2.310000</td>
#       <td id="T_2d928_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_2d928_row0_col5" class="data row0 col5" >0.538000</td>
#       <td id="T_2d928_row0_col6" class="data row0 col6" >6.575000</td>
#       <td id="T_2d928_row0_col7" class="data row0 col7" >65.200000</td>
#       <td id="T_2d928_row0_col8" class="data row0 col8" >4.090000</td>
#       <td id="T_2d928_row0_col9" class="data row0 col9" >1</td>
#       <td id="T_2d928_row0_col10" class="data row0 col10" >296</td>
#       <td id="T_2d928_row0_col11" class="data row0 col11" >15.300000</td>
#       <td id="T_2d928_row0_col12" class="data row0 col12" >396.900000</td>
#       <td id="T_2d928_row0_col13" class="data row0 col13" >4.980000</td>
#       <td id="T_2d928_row0_col14" class="data row0 col14" >24.000000</td>
#     </tr>
#     <tr>
#       <td id="T_2d928_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_2d928_row1_col1" class="data row1 col1" >0.027310</td>
#       <td id="T_2d928_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_2d928_row1_col3" class="data row1 col3" >7.070000</td>
#       <td id="T_2d928_row1_col4" class="data row1 col4" >0</td>
#       <td id="T_2d928_row1_col5" class="data row1 col5" >0.469000</td>
#       <td id="T_2d928_row1_col6" class="data row1 col6" >6.421000</td>
#       <td id="T_2d928_row1_col7" class="data row1 col7" >78.900000</td>
#       <td id="T_2d928_row1_col8" class="data row1 col8" >4.967100</td>
#       <td id="T_2d928_row1_col9" class="data row1 col9" >2</td>
#       <td id="T_2d928_row1_col10" class="data row1 col10" >242</td>
#       <td id="T_2d928_row1_col11" class="data row1 col11" >17.800000</td>
#       <td id="T_2d928_row1_col12" class="data row1 col12" >396.900000</td>
#       <td id="T_2d928_row1_col13" class="data row1 col13" >9.140000</td>
#       <td id="T_2d928_row1_col14" class="data row1 col14" >21.600000</td>
#     </tr>
#     <tr>
#       <td id="T_2d928_row2_col0" class="data row2 col0" >4</td>
#       <td id="T_2d928_row2_col1" class="data row2 col1" >0.032370</td>
#       <td id="T_2d928_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_2d928_row2_col3" class="data row2 col3" >2.180000</td>
#       <td id="T_2d928_row2_col4" class="data row2 col4" >0</td>
#       <td id="T_2d928_row2_col5" class="data row2 col5" >0.458000</td>
#       <td id="T_2d928_row2_col6" class="data row2 col6" >6.998000</td>
#       <td id="T_2d928_row2_col7" class="data row2 col7" >45.800000</td>
#       <td id="T_2d928_row2_col8" class="data row2 col8" >6.062200</td>
#       <td id="T_2d928_row2_col9" class="data row2 col9" >3</td>
#       <td id="T_2d928_row2_col10" class="data row2 col10" >222</td>
#       <td id="T_2d928_row2_col11" class="data row2 col11" >18.700000</td>
#       <td id="T_2d928_row2_col12" class="data row2 col12" >394.630000</td>
#       <td id="T_2d928_row2_col13" class="data row2 col13" >2.940000</td>
#       <td id="T_2d928_row2_col14" class="data row2 col14" >33.400000</td>
#     </tr>
#     <tr>
#       <td id="T_2d928_row3_col0" class="data row3 col0" >5</td>
#       <td id="T_2d928_row3_col1" class="data row3 col1" >0.069050</td>
#       <td id="T_2d928_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_2d928_row3_col3" class="data row3 col3" >2.180000</td>
#       <td id="T_2d928_row3_col4" class="data row3 col4" >0</td>
#       <td id="T_2d928_row3_col5" class="data row3 col5" >0.458000</td>
#       <td id="T_2d928_row3_col6" class="data row3 col6" >7.147000</td>
#       <td id="T_2d928_row3_col7" class="data row3 col7" >54.200000</td>
#       <td id="T_2d928_row3_col8" class="data row3 col8" >6.062200</td>
#       <td id="T_2d928_row3_col9" class="data row3 col9" >3</td>
#       <td id="T_2d928_row3_col10" class="data row3 col10" >222</td>
#       <td id="T_2d928_row3_col11" class="data row3 col11" >18.700000</td>
#       <td id="T_2d928_row3_col12" class="data row3 col12" >396.900000</td>
#       <td id="T_2d928_row3_col13" class="data row3 col13" >5.330000</td>
#       <td id="T_2d928_row3_col14" class="data row3 col14" >36.200000</td>
#     </tr>
#     <tr>
#       <td id="T_2d928_row4_col0" class="data row4 col0" >7</td>
#       <td id="T_2d928_row4_col1" class="data row4 col1" >0.088290</td>
#       <td id="T_2d928_row4_col2" class="data row4 col2" >12.500000</td>
#       <td id="T_2d928_row4_col3" class="data row4 col3" >7.870000</td>
#       <td id="T_2d928_row4_col4" class="data row4 col4" >0</td>
#       <td id="T_2d928_row4_col5" class="data row4 col5" >0.524000</td>
#       <td id="T_2d928_row4_col6" class="data row4 col6" >6.012000</td>
#       <td id="T_2d928_row4_col7" class="data row4 col7" >66.600000</td>
#       <td id="T_2d928_row4_col8" class="data row4 col8" >5.560500</td>
#       <td id="T_2d928_row4_col9" class="data row4 col9" >5</td>
#       <td id="T_2d928_row4_col10" class="data row4 col10" >311</td>
#       <td id="T_2d928_row4_col11" class="data row4 col11" >15.200000</td>
#       <td id="T_2d928_row4_col12" class="data row4 col12" >395.600000</td>
#       <td id="T_2d928_row4_col13" class="data row4 col13" >12.430000</td>
#       <td id="T_2d928_row4_col14" class="data row4 col14" >22.900000</td>
#     </tr>
#   </tbody>
# </table>

# %%
#df_train.head(10)
df_train.head(10).style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_12357_row0_col0, #T_12357_row0_col1, #T_12357_row0_col4, #T_12357_row0_col8, #T_12357_row0_col9, #T_12357_row1_col2, #T_12357_row1_col4, #T_12357_row2_col2, #T_12357_row2_col3, #T_12357_row2_col4, #T_12357_row2_col5, #T_12357_row2_col10, #T_12357_row2_col13, #T_12357_row3_col2, #T_12357_row3_col3, #T_12357_row3_col4, #T_12357_row3_col5, #T_12357_row3_col10, #T_12357_row4_col4, #T_12357_row4_col11, #T_12357_row5_col4, #T_12357_row5_col11, #T_12357_row5_col14, #T_12357_row6_col4, #T_12357_row6_col11, #T_12357_row7_col4, #T_12357_row7_col6, #T_12357_row7_col7, #T_12357_row7_col11, #T_12357_row8_col2, #T_12357_row8_col4, #T_12357_row9_col2, #T_12357_row9_col4, #T_12357_row9_col12 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_12357_row0_col2, #T_12357_row0_col5, #T_12357_row0_col12, #T_12357_row1_col12, #T_12357_row3_col6, #T_12357_row3_col12, #T_12357_row3_col14, #T_12357_row4_col9, #T_12357_row4_col10, #T_12357_row5_col7, #T_12357_row5_col8, #T_12357_row5_col9, #T_12357_row5_col10, #T_12357_row5_col13, #T_12357_row6_col9, #T_12357_row6_col10, #T_12357_row6_col12, #T_12357_row7_col9, #T_12357_row7_col10, #T_12357_row8_col3, #T_12357_row8_col5, #T_12357_row8_col11, #T_12357_row8_col12, #T_12357_row9_col0, #T_12357_row9_col1, #T_12357_row9_col3, #T_12357_row9_col5, #T_12357_row9_col11 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_12357_row0_col3 {
#   background-color: #fff2eb;
#   color: #000000;
# }
# #T_12357_row0_col6 {
#   background-color: #f7593f;
#   color: #f1f1f1;
# }
# #T_12357_row0_col7 {
#   background-color: #fb7252;
#   color: #f1f1f1;
# }
# #T_12357_row0_col10 {
#   background-color: #b21218;
#   color: #f1f1f1;
# }
# #T_12357_row0_col11 {
#   background-color: #fff2ec;
#   color: #000000;
# }
# #T_12357_row0_col13 {
#   background-color: #fee2d5;
#   color: #000000;
# }
# #T_12357_row0_col14, #T_12357_row1_col6 {
#   background-color: #fc8262;
#   color: #f1f1f1;
# }
# #T_12357_row1_col0 {
#   background-color: #fee9df;
#   color: #000000;
# }
# #T_12357_row1_col1 {
#   background-color: #fff0e8;
#   color: #000000;
# }
# #T_12357_row1_col3, #T_12357_row9_col7 {
#   background-color: #b51318;
#   color: #f1f1f1;
# }
# #T_12357_row1_col5, #T_12357_row7_col1 {
#   background-color: #fedccd;
#   color: #000000;
# }
# #T_12357_row1_col7 {
#   background-color: #d32020;
#   color: #f1f1f1;
# }
# #T_12357_row1_col8, #T_12357_row5_col6 {
#   background-color: #fc8e6e;
#   color: #000000;
# }
# #T_12357_row1_col9 {
#   background-color: #fcbba1;
#   color: #000000;
# }
# #T_12357_row1_col10 {
#   background-color: #fcc3ab;
#   color: #000000;
# }
# #T_12357_row1_col11 {
#   background-color: #fb7b5b;
#   color: #f1f1f1;
# }
# #T_12357_row1_col13 {
#   background-color: #fc997a;
#   color: #000000;
# }
# #T_12357_row1_col14 {
#   background-color: #fca78b;
#   color: #000000;
# }
# #T_12357_row2_col0 {
#   background-color: #fdc6b0;
#   color: #000000;
# }
# #T_12357_row2_col1 {
#   background-color: #ffeee7;
#   color: #000000;
# }
# #T_12357_row2_col6 {
#   background-color: #a10e15;
#   color: #f1f1f1;
# }
# #T_12357_row2_col7 {
#   background-color: #fee1d3;
#   color: #000000;
# }
# #T_12357_row2_col8, #T_12357_row3_col8 {
#   background-color: #a50f15;
#   color: #f1f1f1;
# }
# #T_12357_row2_col9, #T_12357_row3_col9 {
#   background-color: #fb694a;
#   color: #f1f1f1;
# }
# #T_12357_row2_col11, #T_12357_row3_col11, #T_12357_row7_col8 {
#   background-color: #f14331;
#   color: #f1f1f1;
# }
# #T_12357_row2_col12 {
#   background-color: #a81016;
#   color: #f1f1f1;
# }
# #T_12357_row2_col14 {
#   background-color: #a60f15;
#   color: #f1f1f1;
# }
# #T_12357_row3_col0 {
#   background-color: #fcaf93;
#   color: #000000;
# }
# #T_12357_row3_col1, #T_12357_row4_col6 {
#   background-color: #fee5d8;
#   color: #000000;
# }
# #T_12357_row3_col7, #T_12357_row8_col8 {
#   background-color: #fcb398;
#   color: #000000;
# }
# #T_12357_row3_col13 {
#   background-color: #fedecf;
#   color: #000000;
# }
# #T_12357_row4_col0 {
#   background-color: #fc8161;
#   color: #f1f1f1;
# }
# #T_12357_row4_col1 {
#   background-color: #fedfd0;
#   color: #000000;
# }
# #T_12357_row4_col2, #T_12357_row5_col2, #T_12357_row6_col2, #T_12357_row7_col2 {
#   background-color: #db2824;
#   color: #f1f1f1;
# }
# #T_12357_row4_col3, #T_12357_row5_col3, #T_12357_row6_col3, #T_12357_row7_col3, #T_12357_row8_col10, #T_12357_row9_col10 {
#   background-color: #7c0510;
#   color: #f1f1f1;
# }
# #T_12357_row4_col5, #T_12357_row5_col5, #T_12357_row6_col5, #T_12357_row7_col5 {
#   background-color: #b31218;
#   color: #f1f1f1;
# }
# #T_12357_row4_col7 {
#   background-color: #fb6b4b;
#   color: #f1f1f1;
# }
# #T_12357_row4_col8 {
#   background-color: #e83429;
#   color: #f1f1f1;
# }
# #T_12357_row4_col12 {
#   background-color: #8c0912;
#   color: #f1f1f1;
# }
# #T_12357_row4_col13 {
#   background-color: #f75b40;
#   color: #f1f1f1;
# }
# #T_12357_row4_col14 {
#   background-color: #fc9373;
#   color: #000000;
# }
# #T_12357_row5_col0 {
#   background-color: #d52221;
#   color: #f1f1f1;
# }
# #T_12357_row5_col1 {
#   background-color: #fc9c7d;
#   color: #000000;
# }
# #T_12357_row5_col12 {
#   background-color: #ce1a1e;
#   color: #f1f1f1;
# }
# #T_12357_row6_col0 {
#   background-color: #bf151b;
#   color: #f1f1f1;
# }
# #T_12357_row6_col1 {
#   background-color: #fdd1be;
#   color: #000000;
# }
# #T_12357_row6_col6 {
#   background-color: #fee5d9;
#   color: #000000;
# }
# #T_12357_row6_col7 {
#   background-color: #bd151a;
#   color: #f1f1f1;
# }
# #T_12357_row6_col8 {
#   background-color: #800610;
#   color: #f1f1f1;
# }
# #T_12357_row6_col13 {
#   background-color: #f24734;
#   color: #f1f1f1;
# }
# #T_12357_row6_col14 {
#   background-color: #fdcebb;
#   color: #000000;
# }
# #T_12357_row7_col0 {
#   background-color: #aa1016;
#   color: #f1f1f1;
# }
# #T_12357_row7_col12 {
#   background-color: #f03d2d;
#   color: #f1f1f1;
# }
# #T_12357_row7_col13 {
#   background-color: #d11e1f;
#   color: #f1f1f1;
# }
# #T_12357_row7_col14 {
#   background-color: #fca689;
#   color: #000000;
# }
# #T_12357_row8_col0 {
#   background-color: #8a0812;
#   color: #f1f1f1;
# }
# #T_12357_row8_col1 {
#   background-color: #6d010e;
#   color: #f1f1f1;
# }
# #T_12357_row8_col6 {
#   background-color: #ffede5;
#   color: #000000;
# }
# #T_12357_row8_col7 {
#   background-color: #fc8666;
#   color: #f1f1f1;
# }
# #T_12357_row8_col9, #T_12357_row9_col9 {
#   background-color: #ca181d;
#   color: #f1f1f1;
# }
# #T_12357_row8_col13 {
#   background-color: #fcaa8d;
#   color: #000000;
# }
# #T_12357_row8_col14 {
#   background-color: #fcb99f;
#   color: #000000;
# }
# #T_12357_row9_col6, #T_12357_row9_col8 {
#   background-color: #fdd4c2;
#   color: #000000;
# }
# #T_12357_row9_col13 {
#   background-color: #fc8464;
#   color: #f1f1f1;
# }
# #T_12357_row9_col14 {
#   background-color: #fed9c9;
#   color: #000000;
# }
# </style>
# <table id="T_12357" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_12357_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_12357_level0_col1" class="col_heading level0 col1" >crim</th>
#       <th id="T_12357_level0_col2" class="col_heading level0 col2" >zn</th>
#       <th id="T_12357_level0_col3" class="col_heading level0 col3" >indus</th>
#       <th id="T_12357_level0_col4" class="col_heading level0 col4" >chas</th>
#       <th id="T_12357_level0_col5" class="col_heading level0 col5" >nox</th>
#       <th id="T_12357_level0_col6" class="col_heading level0 col6" >rm</th>
#       <th id="T_12357_level0_col7" class="col_heading level0 col7" >age</th>
#       <th id="T_12357_level0_col8" class="col_heading level0 col8" >dis</th>
#       <th id="T_12357_level0_col9" class="col_heading level0 col9" >rad</th>
#       <th id="T_12357_level0_col10" class="col_heading level0 col10" >tax</th>
#       <th id="T_12357_level0_col11" class="col_heading level0 col11" >ptratio</th>
#       <th id="T_12357_level0_col12" class="col_heading level0 col12" >black</th>
#       <th id="T_12357_level0_col13" class="col_heading level0 col13" >lstat</th>
#       <th id="T_12357_level0_col14" class="col_heading level0 col14" >medv</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_12357_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_12357_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_12357_row0_col1" class="data row0 col1" >0.006320</td>
#       <td id="T_12357_row0_col2" class="

# %%
#df_train.tail(10)
df_train.tail(10).style.background_gradient(cmap = 'Blues')
# Out:
# <style type="text/css">
# #T_15476_row0_col0, #T_15476_row0_col2, #T_15476_row0_col4, #T_15476_row0_col6, #T_15476_row0_col8, #T_15476_row0_col12, #T_15476_row0_col14, #T_15476_row1_col2, #T_15476_row1_col4, #T_15476_row2_col2, #T_15476_row2_col4, #T_15476_row3_col2, #T_15476_row3_col3, #T_15476_row3_col4, #T_15476_row3_col7, #T_15476_row3_col11, #T_15476_row4_col2, #T_15476_row4_col3, #T_15476_row4_col4, #T_15476_row4_col11, #T_15476_row5_col2, #T_15476_row5_col3, #T_15476_row5_col4, #T_15476_row5_col11, #T_15476_row6_col2, #T_15476_row6_col4, #T_15476_row6_col5, #T_15476_row6_col9, #T_15476_row6_col10, #T_15476_row7_col1, #T_15476_row7_col2, #T_15476_row7_col4, #T_15476_row7_col5, #T_15476_row7_col9, #T_15476_row7_col10, #T_15476_row8_col2, #T_15476_row8_col4, #T_15476_row8_col5, #T_15476_row8_col9, #T_15476_row8_col10, #T_15476_row8_col13, #T_15476_row9_col2, #T_15476_row9_col4, #T_15476_row9_col5, #T_15476_row9_col9, #T_15476_row9_col10 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_15476_row0_col1 {
#   background-color: #2676b8;
#   color: #f1f1f1;
# }
# #T_15476_row0_col3, #T_15476_row0_col5, #T_15476_row0_col10, #T_15476_row0_col13, #T_15476_row1_col3, #T_15476_row1_col5, #T_15476_row1_col7, #T_15476_row1_col10, #T_15476_row2_col3, #T_15476_row2_col5, #T_15476_row2_col10, #T_15476_row2_col12, #T_15476_row3_col9, #T_15476_row3_col12, #T_15476_row4_col1, #T_15476_row4_col8, #T_15476_row4_col9, #T_15476_row4_col12, #T_15476_row5_col9, #T_15476_row6_col11, #T_15476_row7_col11, #T_15476_row7_col12, #T_15476_row8_col6, #T_15476_row8_col11, #T_15476_row8_col12, #T_15476_row8_col14, #T_15476_row9_col0, #T_15476_row9_col11, #T_15476_row9_col12 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_15476_row0_col7 {
#   background-color: #083471;
#   color: #f1f1f1;
# }
# #T_15476_row0_col9, #T_15476_row1_col9, #T_15476_row2_col9, #T_15476_row5_col0, #T_15476_row9_col7 {
#   background-color: #4a98c9;
#   color: #f1f1f1;
# }
# #T_15476_row0_col11, #T_15476_row1_col11, #T_15476_row2_col11 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_15476_row1_col0, #T_15476_row8_col1 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_15476_row1_col1 {
#   background-color: #bfd8ed;
#   color: #000000;
# }
# #T_15476_row1_col6, #T_15476_row2_col6 {
#   background-color: #77b5d9;
#   color: #000000;
# }
# #T_15476_row1_col8 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_15476_row1_col12 {
#   background-color: #08478d;
#   color: #f1f1f1;
# }
# #T_15476_row1_col13 {
#   background-color: #65aad4;
#   color: #f1f1f1;
# }
# #T_15476_row1_col14 {
#   background-color: #a6cee4;
#   color: #000000;
# }
# #T_15476_row2_col0 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_15476_row2_col1 {
#   background-color: #b8d5ea;
#   color: #000000;
# }
# #T_15476_row2_col7 {
#   background-color: #3989c1;
#   color: #f1f1f1;
# }
# #T_15476_row2_col8, #T_15476_row3_col10, #T_15476_row4_col10, #T_15476_row5_col10 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_15476_row2_col13, #T_15476_row8_col8 {
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_15476_row2_col14 {
#   background-color: #1f6eb3;
#   color: #f1f1f1;
# }
# #T_15476_row3_col0 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_15476_row3_col1 {
#   background-color: #539ecd;
#   color: #f1f1f1;
# }
# #T_15476_row3_col5, #T_15476_row4_col5, #T_15476_row5_col5 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_15476_row3_col6 {
#   background-color: #aed1e7;
#   color: #000000;
# }
# #T_15476_row3_col8 {
#   background-color: #64a9d3;
#   color: #f1f1f1;
# }
# #T_15476_row3_col13 {
#   background-color: #c2d9ee;
#   color: #000000;
# }
# #T_15476_row3_col14, #T_15476_row8_col0 {
#   background-color: #0a539e;
#   color: #f1f1f1;
# }
# #T_15476_row4_col0 {
#   background-color: #79b5d9;
#   color: #000000;
# }
# #T_15476_row4_col6 {
#   background-color: #9fcae1;
#   color: #000000;
# }
# #T_15476_row4_col7 {
#   background-color: #a0cbe2;
#   color: #000000;
# }
# #T_15476_row4_col13 {
#   background-color: #a5cde3;
#   color: #000000;
# }
# #T_15476_row4_col14 {
#   background-color: #3c8cc3;
#   color: #f1f1f1;
# }
# #T_15476_row5_col1, #T_15476_row5_col14 {
#   background-color: #4b98ca;
#   color: #f1f1f1;
# }
# #T_15476_row5_col6 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_15476_row5_col7, #T_15476_row7_col8 {
#   background-color: #85bcdc;
#   color: #000000;
# }
# #T_15476_row5_col8 {
#   background-color: #5da5d1;
#   color: #f1f1f1;
# }
# #T_15476_row5_col12 {
#   background-color: #083370;
#   color: #f1f1f1;
# }
# #T_15476_row5_col13 {
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_15476_row6_col0 {
#   background-color: #2575b7;
#   color: #f1f1f1;
# }
# #T_15476_row6_col1 {
#   background-color: #e8f1fa;
#   color: #000000;
# }
# #T_15476_row6_col3, #T_15476_row7_col3, #T_15476_row8_col3, #T_15476_row9_col3 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_15476_row6_col6 {
#   background-color: #1865ac;
#   color: #f1f1f1;
# }
# #T_15476_row6_col7 {
#   background-color: #aacfe5;
#   color: #000000;
# }
# #T_15476_row6_col8 {
#   background-color: #4695c8;
#   color: #f1f1f1;
# }
# #T_15476_row6_col12 {
#   background-color: #084184;
#   color: #f1f1f1;
# }
# #T_15476_row6_col13 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_15476_row6_col14 {
#   background-color: #084990;
#   color: #f1f1f1;
# }
# #T_15476_row7_col0 {
#   background-color: #1764ab;
#   color: #f1f1f1;
# }
# #T_15476_row7_col6 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_15476_row7_col7 {
#   background-color: #69add5;
#   color: #f1f1f1;
# }
# #T_15476_row7_col13 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_15476_row7_col14 {
#   background-color: #1966ad;
#   color: #f1f1f1;
# }
# #T_15476_row8_col7 {
#   background-color: #125da6;
#   color: #f1f1f1;
# }
# #T_15476_row9_col1 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_15476_row9_col6 {
#   background-color: #6caed6;
#   color: #f1f1f1;
# }
# #T_15476_row9_col8 {
#   background-color: #3e8ec4;
#   color: #f1f1f1;
# }
# #T_15476_row9_col13 {
#   background-color: #e5eff9;
#   color: #000000;
# }
# #T_15476_row9_col14 {
#   background-color: #c8dcf0;
#   color: #000000;
# }
# </style>
# <table id="T_15476" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_15476_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_15476_level0_col1" class="col_heading level0 col1" >crim</th>
#       <th id="T_15476_level0_col2" class="col_heading level0 col2" >zn</th>
#       <th id="T_15476_level0_col3" class="col_heading level0 col3" >indus</th>
#       <th id="T_15476_level0_col4" class="col_heading level0 col4" >chas</th>
#       <th id="T_15476_level0_col5" class="col_heading level0 col5" >nox</th>
#       <th id="T_15476_level0_col6" class="col_heading level0 col6" >rm</th>
#       <th id="T_15476_level0_col7" class="col_heading level0 col7" >age</th>
#       <th id="T_15476_level0_col8" class="col_heading level0 col8" >dis</th>
#       <th id="T_15476_level0_col9" class="col_heading level0 col9" >rad</th>
#       <th id="T_15476_level0_col10" class="col_heading level0 col10" >tax</th>
#       <th id="T_15476_level0_col11" class="col_heading level0 col11" >ptratio</th>
#       <th id="T_15476_level0_col12" class="col_heading level0 col12" >black</th>
#       <th id="T_15476_level0_col13" class="col_heading level0 col13" >lstat</th>
#       <th id="T_15476_level0_col14" class="col_heading level0 col14" >medv</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_15476_level0_row0" class="row_heading level0 row0" >323</th>
#       <td id="T_15476_row0_col0" class="data row0 col0" >491</td>
#       <td id="T_15476_row0_col1" class="data row0 col1" >0.207460</td>
#       <td id="T_15476_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_15476_row0_col3" class="data row0 col3" >27.740000</td>
#       <td id="T_15476_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_15476_row0_col5" class="data row0 col5" >0.609000</td>
#       <td id="T_15476_row0_col6" class="data row0 col6" >5.093000</td>
#       <td id="T_15476_row0_col7" class="data row0 col7" >98.000000</td>
#       <td id="T_15476_row0_col8" class="data row0 col8" >1.822600</td>
#       <td id="T_15476_row0_col9" class="data

# %%
#df_train.sample(10)
df_train.sample(10).style.background_gradient()
# Out:
# <style type="text/css">
# #T_51c81_row0_col0, #T_51c81_row6_col8 {
#   background-color: #97b7d7;
#   color: #000000;
# }
# #T_51c81_row0_col1, #T_51c81_row0_col3, #T_51c81_row0_col4, #T_51c81_row0_col10, #T_51c81_row0_col11, #T_51c81_row0_col13, #T_51c81_row1_col1, #T_51c81_row1_col4, #T_51c81_row1_col5, #T_51c81_row1_col7, #T_51c81_row1_col9, #T_51c81_row2_col2, #T_51c81_row2_col4, #T_51c81_row2_col8, #T_51c81_row2_col12, #T_51c81_row2_col14, #T_51c81_row3_col0, #T_51c81_row3_col1, #T_51c81_row3_col2, #T_51c81_row3_col4, #T_51c81_row4_col2, #T_51c81_row4_col4, #T_51c81_row4_col6, #T_51c81_row5_col4, #T_51c81_row6_col10, #T_51c81_row7_col2, #T_51c81_row7_col4, #T_51c81_row8_col2, #T_51c81_row8_col4, #T_51c81_row9_col2, #T_51c81_row9_col4 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_51c81_row0_col2, #T_51c81_row0_col6, #T_51c81_row0_col14, #T_51c81_row2_col1, #T_51c81_row2_col5, #T_51c81_row2_col9, #T_51c81_row2_col11, #T_51c81_row2_col13, #T_51c81_row3_col12, #T_51c81_row4_col9, #T_51c81_row4_col11, #T_51c81_row5_col8, #T_51c81_row6_col4, #T_51c81_row8_col0, #T_51c81_row8_col3, #T_51c81_row8_col10, #T_51c81_row8_col12, #T_51c81_row9_col7, #T_51c81_row9_col9, #T_51c81_row9_col11 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_51c81_row0_col5, #T_51c81_row3_col9, #T_51c81_row8_col8 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_51c81_row0_col7, #T_51c81_row1_col11 {
#   background-color: #e4e1ef;
#   color: #000000;
# }
# #T_51c81_row0_col8 {
#   background-color: #65a3cb;
#   color: #f1f1f1;
# }
# #T_51c81_row0_col9, #T_51c81_row7_col9, #T_51c81_row8_col9 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_51c81_row0_col12, #T_51c81_row5_col12, #T_51c81_row6_col12, #T_51c81_row8_col11, #T_51c81_row9_col5 {
#   background-color: #023c5f;
#   color: #f1f1f1;
# }
# #T_51c81_row1_col0 {
#   background-color: #9fbad9;
#   color: #000000;
# }
# #T_51c81_row1_col2 {
#   background-color: #348ebf;
#   color: #f1f1f1;
# }
# #T_51c81_row1_col3, #T_51c81_row8_col1 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_51c81_row1_col6 {
#   background-color: #b5c4df;
#   color: #000000;
# }
# #T_51c81_row1_col8 {
#   background-color: #167bb6;
#   color: #f1f1f1;
# }
# #T_51c81_row1_col10, #T_51c81_row6_col9 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_51c81_row1_col12 {
#   background-color: #03476f;
#   color: #f1f1f1;
# }
# #T_51c81_row1_col13 {
#   background-color: #f4edf6;
#   color: #000000;
# }
# #T_51c81_row1_col14, #T_51c81_row5_col0 {
#   background-color: #75a9cf;
#   color: #f1f1f1;
# }
# #T_51c81_row2_col0 {
#   background-color: #045e94;
#   color: #f1f1f1;
# }
# #T_51c81_row2_col3, #T_51c81_row4_col3, #T_51c81_row9_col3 {
#   background-color: #3b92c1;
#   color: #f1f1f1;
# }
# #T_51c81_row2_col6, #T_51c81_row4_col13 {
#   background-color: #8fb4d6;
#   color: #000000;
# }
# #T_51c81_row2_col7 {
#   background-color: #1278b4;
#   color: #f1f1f1;
# }
# #T_51c81_row2_col10, #T_51c81_row4_col10, #T_51c81_row9_col10 {
#   background-color: #03517e;
#   color: #f1f1f1;
# }
# #T_51c81_row3_col3 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# #T_51c81_row3_col5, #T_51c81_row6_col2 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_51c81_row3_col6 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_51c81_row3_col7 {
#   background-color: #0570b0;
#   color: #f1f1f1;
# }
# #T_51c81_row3_col8 {
#   background-color: #71a8ce;
#   color: #f1f1f1;
# }
# #T_51c81_row3_col10, #T_51c81_row8_col6 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_51c81_row3_col11 {
#   background-color: #549cc7;
#   color: #f1f1f1;
# }
# #T_51c81_row3_col13, #T_51c81_row5_col13 {
#   background-color: #bbc7e0;
#   color: #000000;
# }
# #T_51c81_row3_col14 {
#   background-color: #b9c6e0;
#   color: #000000;
# }
# #T_51c81_row4_col0 {
#   background-color: #023a5b;
#   color: #f1f1f1;
# }
# #T_51c81_row4_col1, #T_51c81_row6_col7 {
#   background-color: #99b8d8;
#   color: #000000;
# }
# #T_51c81_row4_col5 {
#   background-color: #509ac6;
#   color: #f1f1f1;
# }
# #T_51c81_row4_col7 {
#   background-color: #91b5d6;
#   color: #000000;
# }
# #T_51c81_row4_col8 {
#   background-color: #d8d7e9;
#   color: #000000;
# }
# #T_51c81_row4_col12 {
#   background-color: #023e62;
#   color: #f1f1f1;
# }
# #T_51c81_row4_col14 {
#   background-color: #c1cae2;
#   color: #000000;
# }
# #T_51c81_row5_col1 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_51c81_row5_col2 {
#   background-color: #d4d4e8;
#   color: #000000;
# }
# #T_51c81_row5_col3 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_51c81_row5_col5, #T_51c81_row5_col6 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_51c81_row5_col7 {
#   background-color: #dbdaeb;
#   color: #000000;
# }
# #T_51c81_row5_col9 {
#   background-color: #cdd0e5;
#   color: #000000;
# }
# #T_51c81_row5_col10 {
#   background-color: #d7d6e9;
#   color: #000000;
# }
# #T_51c81_row5_col11 {
#   background-color: #0567a2;
#   color: #f1f1f1;
# }
# #T_51c81_row5_col14 {
#   background-color: #a4bcda;
#   color: #000000;
# }
# #T_51c81_row6_col0 {
#   background-color: #5a9ec9;
#   color: #f1f1f1;
# }
# #T_51c81_row6_col1 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_51c81_row6_col3 {
#   background-color: #e2dfee;
#   color: #000000;
# }
# #T_51c81_row6_col5 {
#   background-color: #dcdaeb;
#   color: #000000;
# }
# #T_51c81_row6_col6 {
#   background-color: #046097;
#   color: #f1f1f1;
# }
# #T_51c81_row6_col11 {
#   background-color: #157ab5;
#   color: #f1f1f1;
# }
# #T_51c81_row6_col13 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_51c81_row6_col14 {
#   background-color: #2f8bbe;
#   color: #f1f1f1;
# }
# #T_51c81_row7_col0 {
#   background-color: #2d8abd;
#   color: #f1f1f1;
# }
# #T_51c81_row7_col1 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_51c81_row7_col3 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_51c81_row7_col5 {
#   background-color: #88b1d4;
#   color: #000000;
# }
# #T_51c81_row7_col6, #T_51c81_row9_col14 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_51c81_row7_col7 {
#   background-color: #4295c3;
#   color: #f1f1f1;
# }
# #T_51c81_row7_col8 {
#   background-color: #c6cce3;
#   color: #000000;
# }
# #T_51c81_row7_col10 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_51c81_row7_col11 {
#   background-color: #2383ba;
#   color: #f1f1f1;
# }
# #T_51c81_row7_col12 {
#   background-color: #02395a;
#   color: #f1f1f1;
# }
# #T_51c81_row7_col13 {
#   background-color: #a5bddb;
#   color: #000000;
# }
# #T_51c81_row7_col14 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# #T_51c81_row8_col5 {
#   background-color: #2a88bc;
#   color: #f1f1f1;
# }
# #T_51c81_row8_col7 {
#   background-color: #0567a1;
#   color: #f1f1f1;
# }
# #T_51c81_row8_col13 {
#   background-color: #67a4cc;
#   color: #f1f1f1;
# }
# #T_51c81_row8_col14 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T_51c81_row9_col0 {
#   background-color: #034d79;
#   color: #f1f1f1;
# }
# #T_51c81_row9_col1, #T_51c81_row9_col6, #T_51c81_row9_col13 {
#   background-color: #197db7;
#   color: #f1f1f1;
# }
# #T_51c81_row9_col8 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_51c81_row9_col12 {
#   background-color: #034871;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_51c81" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_51c81_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_51c81_level0_col1" class="col_heading level0 col1" >crim</th>
#       <th id="T_51c81_level0_col2" class="col_heading level0 col2" >zn</th>
#       <th id="T_51c81_level0_col3" class="col_heading level0 col3" >indus</th>
#       <th id="T_51c81_level0_col4" class="col_heading level0 col4" >chas</th>
#       <th id="T_51c81_level0_col5" class="col_heading level0 col5" >nox</th>
#       <th id="T_51c81_level0_col6" class="col_heading level0 col6" >rm</th>
#       <th id="T_51c81_level0_col7" class="col_heading level0 col7" >age</th>
#       <th id="T_51c81_level0_col8" class="col_heading level0 col8" >dis</th>
#       <th id="T_51c81_level0_col9" class="col_heading level0 col9" >rad</th>
#       <th id="T_51c81_level0_col10" class="col_heading level0 col10" >tax</th>
#       <th id="T_51c81_level0_col11" class="col_heading level0 col11" >ptratio</th>
#       <th id="T_51c81_level0_col12" class="col_heading level0 col12" >black</th>
#       <th id="T_51c81_level0_col13" class="col_head

# %%
df_train.shape
# Out:
# (333, 15)

# %%
df_train.columns
# Out:
# Index(['ID', 'crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad',
#        'tax', 'ptratio', 'black', 'lstat', 'medv'],
#       dtype='object')

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 333 entries, 0 to 332
# Data columns (total 15 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   ID       333 non-null    int64
#  1   crim     333 non-null    float64
#  2   zn       333 non-null    float64
#  3   indus    333 non-null    float64
#  4   chas     333 non-null    int64
#  5   nox      333 non-null    float64
#  6   rm       333 non-null    float64
#  7   age      333 non-null    float64
#  8   dis      333 non-null    float64
#  9   rad      333 non-null    int64
#  10  tax      333 non-null    int64
#  11  ptratio  333 non-null    float64
#  12  black    333 non-null    float64
#  13  lstat    333 non-null    float64
#  14  medv     333 non-null    float64
# dtypes: float64(11), int64(4)
# memory usage: 39.1 KB

# %%
df_train.isnull().sum()
# Out:
# ID         0
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# black      0
# lstat      0
# medv       0
# dtype: int64

# %%
df_train.isna().sum()
# Out:
# ID         0
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# black      0
# lstat      0
# medv       0
# dtype: int64

# %%
plt.rcParams['figure.figsize'] = [12, 8]#resize the plot
#plt.figure(figsize = (12, 8))

df_train.plot()
plt.show()

# %%
#df_train.describe()
#df_train.describe().T
df_train.describe().T.style.background_gradient()
# Out:
# <style type="text/css">
# #T_cae9c_row0_col0, #T_cae9c_row1_col0, #T_cae9c_row1_col3, #T_cae9c_row1_col4, #T_cae9c_row1_col5, #T_cae9c_row2_col0, #T_cae9c_row2_col3, #T_cae9c_row2_col4, #T_cae9c_row2_col5, #T_cae9c_row3_col0, #T_cae9c_row4_col0, #T_cae9c_row4_col1, #T_cae9c_row4_col2, #T_cae9c_row4_col3, #T_cae9c_row4_col4, #T_cae9c_row4_col5, #T_cae9c_row4_col6, #T_cae9c_row4_col7, #T_cae9c_row5_col0, #T_cae9c_row5_col1, #T_cae9c_row5_col2, #T_cae9c_row5_col3, #T_cae9c_row5_col4, #T_cae9c_row5_col5, #T_cae9c_row5_col6, #T_cae9c_row5_col7, #T_cae9c_row6_col0, #T_cae9c_row6_col2, #T_cae9c_row7_col0, #T_cae9c_row8_col0, #T_cae9c_row9_col0, #T_cae9c_row10_col0, #T_cae9c_row11_col0, #T_cae9c_row12_col0, #T_cae9c_row13_col0, #T_cae9c_row14_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_cae9c_row0_col1 {
#   background-color: #3d93c2;
#   color: #f1f1f1;
# }
# #T_cae9c_row0_col2 {
#   background-color: #045b8f;
#   color: #f1f1f1;
# }
# #T_cae9c_row0_col3, #T_cae9c_row1_col6, #T_cae9c_row3_col3, #T_cae9c_row8_col3, #T_cae9c_row8_col4, #T_cae9c_row8_col6, #T_cae9c_row9_col3 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_cae9c_row0_col4 {
#   background-color: #b7c5df;
#   color: #000000;
# }
# #T_cae9c_row0_col5 {
#   background-color: #3790c0;
#   color: #f1f1f1;
# }
# #T_cae9c_row0_col6 {
#   background-color: #549cc7;
#   color: #f1f1f1;
# }
# #T_cae9c_row0_col7 {
#   background-color: #1379b5;
#   color: #f1f1f1;
# }
# #T_cae9c_row1_col1, #T_cae9c_row6_col6, #T_cae9c_row6_col7, #T_cae9c_row8_col1, #T_cae9c_row8_col2, #T_cae9c_row8_col5, #T_cae9c_row9_col4, #T_cae9c_row13_col3 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_cae9c_row1_col2, #T_cae9c_row3_col2, #T_cae9c_row13_col2 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_cae9c_row1_col7 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_cae9c_row2_col1, #T_cae9c_row3_col5, #T_cae9c_row3_col6, #T_cae9c_row13_col6, #T_cae9c_row14_col3 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_cae9c_row2_col2 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_cae9c_row2_col6, #T_cae9c_row3_col4, #T_cae9c_row6_col1, #T_cae9c_row6_col3, #T_cae9c_row6_col4, #T_cae9c_row6_col5, #T_cae9c_row8_col7, #T_cae9c_row9_col5, #T_cae9c_row11_col2, #T_cae9c_row12_col3, #T_cae9c_row13_col4 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_cae9c_row2_col7, #T_cae9c_row7_col7 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_cae9c_row3_col1, #T_cae9c_row11_col6, #T_cae9c_row11_col7, #T_cae9c_row13_col1, #T_cae9c_row13_col5 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_cae9c_row3_col7, #T_cae9c_row9_col6, #T_cae9c_row14_col6 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_cae9c_row7_col1, #T_cae9c_row7_col2 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_cae9c_row7_col3, #T_cae9c_row9_col7 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_cae9c_row7_col4 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_cae9c_row7_col5 {
#   background-color: #dcdaeb;
#   color: #000000;
# }
# #T_cae9c_row7_col6 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_cae9c_row9_col1 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_cae9c_row9_col2, #T_cae9c_row11_col1, #T_cae9c_row11_col4, #T_cae9c_row11_col5, #T_cae9c_row14_col4 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_cae9c_row10_col1, #T_cae9c_row10_col2, #T_cae9c_row10_col3, #T_cae9c_row10_col6, #T_cae9c_row10_col7, #T_cae9c_row12_col4, #T_cae9c_row12_col5 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_cae9c_row10_col4 {
#   background-color: #0872b1;
#   color: #f1f1f1;
# }
# #T_cae9c_row10_col5 {
#   background-color: #046096;
#   color: #f1f1f1;
# }
# #T_cae9c_row11_col3, #T_cae9c_row14_col7 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_cae9c_row12_col1 {
#   background-color: #04598c;
#   color: #f1f1f1;
# }
# #T_cae9c_row12_col2 {
#   background-color: #71a8ce;
#   color: #f1f1f1;
# }
# #T_cae9c_row12_col6 {
#   background-color: #4496c3;
#   color: #f1f1f1;
# }
# #T_cae9c_row12_col7 {
#   background-color: #589ec8;
#   color: #f1f1f1;
# }
# #T_cae9c_row13_col7, #T_cae9c_row14_col1, #T_cae9c_row14_col2, #T_cae9c_row14_col5 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# </style>
# <table id="T_cae9c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cae9c_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_cae9c_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_cae9c_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_cae9c_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_cae9c_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_cae9c_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_cae9c_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_cae9c_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cae9c_level0_row0" class="row_heading level0 row0" >ID</th>
#       <td id="T_cae9c_row0_col0" class="data row0 col0" >333.000000</td>
#       <td id="T_cae9c_row0_col1" class="data row0 col1" >250.951952</td>
#       <td id="T_cae9c_row0_col2" class="data row0 col2" >147.859438</td>
#       <td id="T_cae9c_row0_col3" class="data row0 col3" >1.000000</td>
#       <td id="T_cae9c_row0_col4" class="data row0 col4" >123.000000</td>
#       <td id="T_cae9c_row0_col5" class="data row0 col5" >244.000000</td>
#       <td id="T_cae9c_row0_col6" class="data row0 col6" >377.000000</td>
#       <td id="T_cae9c_row0_col7" class="data row0 col7" >506.000000</td>
#     </tr>
#     <tr>
#       <th id="T_cae9c_level0_row1" class="row_heading level0 row1" >crim</th>
#       <td id="T_cae9c_row1_col0" class="data row1 col0" >333.000000</td>
#       <td id="T_cae9c_row1_col1" class="data row1 col1" >3.360341</td>
#       <td id="T_cae9c_row1_col2" class="data row1 col2" >7.352272</td>
#       <td id="T_cae9c_row1_col3" class="data row1 col3" >0.006320</td>
#       <td id="T_cae9c_row1_col4" class="data row1 col4" >0.078960</td>
#       <td id="T_cae9c_row1_col5" class="data row1 col5" >0.261690</td>
#       <td id="T_cae9c_row1_col6" class="data row1 col6" >3.678220</td>
#       <td id="T_cae9c_row1_col7" class="data row1 col7" >73.534100</td>
#     </tr>
#     <tr>
#       <th id="T_cae9c_level0_row2" class="row_heading level0 row2" >zn</th>
#       <td id="T_cae9c_row2_col0" class="data row2 col0" >333.000000</td>
#       <td id="T_cae9c_row2_col1" class="data row2 col1" >10.689189</td>
#       <td id="T_cae9c_row2_col2" class="data row2 col2" >22.674762</td>
#       <td id="T_cae9c_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_cae9c_row2_col4" class="data row2 col4" >0.000000</td>
#       <td id="T_cae9c_row2_col5" class="data row2 col5" >0.000000</td>
#       <td id="T_cae9c_row2_col6" class="data row2 col6" >12.500000</td>
#       <td id="T_cae9c_row2_col7" class="data row2 col7" >100.000000</td>
#     </tr>
#     <tr>
#       <th id="T_cae9c_level0_row3" class="row_heading level0 row3" >indus</th>
#       <td id="T_cae9c_row3_col0" class="data row3 col0" >333.000000</td>
#       <td id="T_cae9c_row3_col1" class="data row3 col1" >11.293483</td>
#       <td id="T_cae9c_row3_col2" class="data row3 col2" >6.998123</td>
#       <td id="T_cae9c_row3_col3" class="data row3 col3" >0.740000</td>
#       <td id="T_cae9c_row3_col4" class="data row3 col4" >5.130000</td>
#       <td id="T_cae9c_row3_col5" class="data row3 col5" >9.900000</td>
#       <td id="T_cae9c_row3_col6" class="data row3 col6" >18.100000</td>
#       <td id="T_cae9c_row3_col7" class="data row3 col7" >27.740000</td>
#     </tr>
#     <tr>
#       <th id="T_cae9c_level0_row4" class="row_heading level0 row4" >chas</th>
#       <td id="T_cae9c_row4_col0" class="data row4 col0" >333.000000</td>
#       <td id="T_cae9c_row4_col1" class="data row4 col1" >0.060060</td>
#       <td id="T_cae9c_row4_col2" class="data row4 col2" >0.237956</td>
#       <td id="T_cae9c_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_cae9c_row4_col4" class="data row4 col4" >0.000000<

# %%
df_train.mean()
# Out:
# ID         250.951952
# crim         3.360341
# zn          10.689189
# indus       11.293483
# chas         0.060060
# nox          0.557144
# rm           6.265619
# age         68.226426
# dis          3.709934
# rad          9.633634
# tax        409.279279
# ptratio     18.448048
# black      359.466096
# lstat       12.515435
# medv        22.768769
# dtype: float64

# %%
#ID columns does not relevant for our analysis.
df_train.drop('ID', axis = 1, inplace=True)

# %%
df_train.plot.scatter('rm', 'medv');

# %%
# Correlation
plt.subplots(figsize=(16,12))
correlation = df_train.corr().round(2)
sns_plot=sns.heatmap(correlation, annot=True)

#plt.figure(figsize= (18,15))
#sns.heatmap(correlation, cbar=True, square=True, fmt='.2f', annot=True, annot_kws={'size':10}, cmap='Greens')

# %%
# correlation values of Gold
print(correlation['medv'])
# Out:
# crim      -0.41
# zn         0.34
# indus     -0.47
# chas       0.20
# nox       -0.41
# rm         0.69
# age       -0.36
# dis        0.25
# rad       -0.35
# tax       -0.45
# ptratio   -0.48
# black      0.34
# lstat     -0.74
# medv       1.00
# Name: medv, dtype: float64

# %%
sns.pairplot(df_train, vars = ['lstat', 'ptratio', 'indus', 'tax', 'crim', 'nox', 'rad', 'age', 'medv'])

# %%
sns.pairplot(df_train, vars = ['rm', 'zn', 'black', 'dis', 'chas','medv'])

# %%
plt.scatter(df_train.rm , df_train.medv, color="black")
#df_train.plot.scatter('rm', 'medv')
plt.xlabel("rm")
plt.ylabel("medv")
plt.show()

# %%
plt.scatter(df_train.lstat, df_train.medv, color="black")
#df_train.plot.scatter('lstat' ,'medv')
plt.xlabel("lstat")
plt.ylabel("medv")
plt.show()

# %%
plt.scatter(df_train.ptratio,df_train.medv, color="Blue")
#df_train.plot.scatter('ptratio', 'medv')
plt.xlabel("ptratio")
plt.ylabel("medv")
plt.show()

# %%
plt.scatter(df_train.tax, df_train.medv, color="Red")
#df_train.plot.scatter('tax', 'medv')
plt.xlabel("tax")
plt.ylabel("medv")
plt.show()

# %%
X = df_train[['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
       'ptratio', 'black', 'lstat']]
y = df_train['medv']

# %%
# Split arrays or matrices into random train and test subsets
#random_state #Testing the model with 20% of the dataset & training it with 80% of the model
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20 , random_state=0)

# %%
LR = LinearRegression()
LR.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print("Accuracy --> ", LR.score(X_test, y_test)*100)
# Out:
# Accuracy -->  73.12411054098573

# %%
predictions = LR.predict(X_test)

# %%
# R Squared error
error_score = metrics.r2_score(y_test, predictions) # coefficient of determination, regression score function.
print('R squared error : ', error_score *100)
# Out:
# R squared error :  73.12411054098573

# %%
regressor = RandomForestRegressor(n_estimators=100)
regressor
# Out:
# RandomForestRegressor()

# %%
# training the model
regressor.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
print("Accuracy --> ", regressor.score(X_test, y_test)*100)
# Out:
# Accuracy -->  90.38797455893423

# %%
# prediction on Test Data
test_data_prediction = regressor.predict(X_test)

# %%
# R Squared error
error_score = metrics.r2_score(y_test, test_data_prediction) # coefficient of determination, regression score function.
print('R squared error : ', error_score *100)
# Out:
# R squared error :  90.38797455893423

# %%
GBR = GradientBoostingRegressor(n_estimators=100, max_depth=4)
gbr = regressor.fit(X_train,y_train)

# %%
print("Accuracy --> ",gbr.score(X_test, y_test)*100)
# Out:
# Accuracy -->  90.56739849617622

# %%
# prediction on Test Data
test_data_prediction1 = gbr.predict(X_test)

# %%
# R Squared error
error_score = metrics.r2_score(y_test, test_data_prediction1 ) # coefficient of determination, regression score function.
print('R squared error : ', error_score *100)
# Out:
# R squared error :  90.56739849617622
